# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """

    # NOTE: I realize I can write this a lot more concisely with list comprehension
    # I prefer it explicit.
    
    # Source text to IDs
    source_id_text = []
    for sentence in source_text.split('\n'):
        sentence_ids = []
        for word in sentence.split():
            sentence_ids.append(source_vocab_to_int[word])
        source_id_text.append(sentence_ids)
    
    # Dest text to IDs
    target_id_text = []
    for sentence in target_text.split('\n'):
        sentence_ids = []
        for word in sentence.split():
            sentence_ids.append(target_vocab_to_int[word])
        sentence_ids.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(sentence_ids)
        
    print(len(source_id_text), len(target_id_text))
    return (source_id_text, target_id_text)

    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# 4 4
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)
# Out:
# 137861 137861

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /disk1/scratch/ml/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    
    # Create TF placeholders to find in data into the graph
    inputs  = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='target')
    learning_rate = tf.placeholder(tf.float32,name='learning_rate')
    keep_prob     = tf.placeholder(tf.float32, name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32,[None],name='target_sequence_length')
    max_target_len         = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, [None],name='source_sequence_length')
    
    return inputs, targets, learning_rate, keep_prob,target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # Use strided_slice to "cut out" out non-needed data
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    
    # Use tf to get embeddings from input data
    enc_embed_input = tf.contrib.layers.embed_sequence(
        rnn_inputs, source_vocab_size, encoding_embedding_size)

    # Inner funtion to create LSTM cells 
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.LSTMCell(
            rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        
        # Add dropout defined by keep_prob argument
        enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, keep_prob)
        return enc_cell

    # Create num_layers LSTM cells
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    # Create RNN from LSTM cells
    enc_output, enc_state = tf.nn.dynamic_rnn(
        enc_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    
    # Training Helper: Helper for the training process. Used by BasicDecoder to read inputs.
    seq2seq_training_helper = tf.contrib.seq2seq.TrainingHelper(
        inputs=dec_embed_input, sequence_length=target_sequence_length, 
        time_major=False)

    # Basic Decoder
    seq2seq_training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, 
                                                       seq2seq_training_helper,
                                                       encoder_state, 
                                                       output_layer)
    # Dynamic Decode
    seq2seq_training_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(
        seq2seq_training_decoder, impute_finished=True,
        maximum_iterations=max_summary_length)

    logits    = seq2seq_training_decoder_output.rnn_output
    sample_id = seq2seq_training_decoder_output.sample_id
    
    # keep_prob dropout  
    logits    = tf.nn.dropout(logits, keep_prob)
    
    return tf.contrib.seq2seq.BasicDecoderOutput(logits, sample_id)



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    
    # start_token
    start_tokens = tf.tile(
        tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], 
        name='start_tokens')

    # Embedding Helper
    seq2seq_embedding_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(
        dec_embeddings, start_tokens, end_of_sequence_id)
    
    # Basic decoder
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                              seq2seq_embedding_helper,
                                              encoder_state,
                                              output_layer)
    
    # Perform dynamic decoding using the decoder
    decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(
        decoder, impute_finished=True,
        maximum_iterations=max_target_sequence_length)

    logits    = decoder_output.rnn_output
    sample_id = decoder_output.sample_id
    logits    = tf.nn.dropout(logits, keep_prob)
    
    return tf.contrib.seq2seq.BasicDecoderOutput(logits, sample_id)   

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # 1. Decoder embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size,
                                                    decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    # 2. Inner function to construct the decoder LSTM cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(
            rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        
        # Add dropout based on keep_prob
        dropout = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
        return dropout
    
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])

    # 3. Create an output layer 
    output_layer = Dense(target_vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0,
                                                                              stddev=0.1))
    
    # 4. Dense layer to translate the decoder's output
    with tf.variable_scope("decode"):
        train_logits = decoding_layer_train(encoder_state, 
                                            dec_cell, 
                                            dec_embed_input, 
                                            target_sequence_length,
                                            max_target_sequence_length, 
                                            output_layer, 
                                            keep_prob) 
    
    # 5. Inference decoder creation
    with tf.variable_scope("decode", reuse=True):
        infer_logits = decoding_layer_infer(encoder_state, 
                                            dec_cell, 
                                            dec_embeddings, 
                                            target_vocab_to_int['<GO>'], 
                                            target_vocab_to_int['<EOS>'],
                                            max_target_sequence_length, 
                                            target_vocab_size,
                                            output_layer, 
                                            batch_size,
                                            keep_prob)

    return train_logits, infer_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # Pass the input data through the encoder, only use the state
    _, enc_state = encoding_layer(input_data, 
                               rnn_size, 
                               num_layers,
                               keep_prob,
                               source_sequence_length,
                               source_vocab_size, 
                               enc_embedding_size)
    
    
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output = decoding_layer(
        dec_input, 
        enc_state, 
        target_sequence_length,
        max_target_sentence_length, 
        rnn_size, 
        num_layers,
        target_vocab_to_int,
        target_vocab_size, 
        batch_size,
        keep_prob, 
        dec_embedding_size)
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 5
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.005
# Dropout Keep Probability
keep_probability = 0.7
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.2979, Validation Accuracy: 0.3739, Loss: 4.0573
# Epoch   0 Batch   20/538 - Train Accuracy: 0.3733, Validation Accuracy: 0.4055, Loss: 3.6733
# Epoch   0 Batch   30/538 - Train Accuracy: 0.3762, Validation Accuracy: 0.4375, Loss: 3.4917
# Epoch   0 Batch   40/538 - Train Accuracy: 0.4780, Validation Accuracy: 0.4730, Loss: 3.2019
# Epoch   0 Batch   50/538 - Train Accuracy: 0.4127, Validation Accuracy: 0.4592, Loss: 3.0999
# Epoch   0 Batch   60/538 - Train Accuracy: 0.4275, Validation Accuracy: 0.4775, Loss: 2.8980
# Epoch   0 Batch   70/538 - Train Accuracy: 0.4362, Validation Accuracy: 0.4666, Loss: 2.7177
# Epoch   0 Batch   80/538 - Train Accuracy: 0.4012, Validation Accuracy: 0.4759, Loss: 2.5491
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4431, Validation Accuracy: 0.4712, Loss: 2.3569
# Epoch   0 Batch  100/538 - Train Accuracy: 0.4832, Validation Accuracy: 0.4970, Loss: 2.3099
# Epoch   0 Batch  110/538 - Train Accuracy: 0.4822, Validation Accuracy: 0.5366, Loss: 2.2829
# Epoch   0 Batch  120/538 - Train Accuracy: 0.4928, Validation Accuracy: 0.5304, Loss: 2.1786
# Epoch   0 Batch  130/538 - Train Accuracy: 0.5392, Validation Accuracy: 0.5387, Loss: 2.0822
# Epoch   0 Batch  140/538 - Train Accuracy: 0.4934, Validation Accuracy: 0.5497, Loss: 2.2032
# Epoch   0 Batch  150/538 - Train Accuracy: 0.5299, Validation Accuracy: 0.5316, Loss: 2.0649
# Epoch   0 Batch  160/538 - Train Accuracy: 0.5417, Validation Accuracy: 0.5627, Loss: 2.0236
# Epoch   0 Batch  170/538 - Train Accuracy: 0.5619, Validation Accuracy: 0.5762, Loss: 2.0282
# Epoch   0 Batch  180/538 - Train Accuracy: 0.5800, Validation Accuracy: 0.5630, Loss: 2.0375
# Epoch   0 Batch  190/538 - Train Accuracy: 0.5988, Validation Accuracy: 0.5909, Loss: 1.9812
# Epoch   0 Batch  200/538 - Train Accuracy: 0.5822, Validation Accuracy: 0.5845, Loss: 1.9942
# Epoch   0 Batch  210/538 - Train Accuracy: 0.5452, Validation Accuracy: 0.5806, Loss: 1.9918
# Epoch   0 Batch  220/538 - Train Accuracy: 0.5772, Validation Accuracy: 0.6025, Loss: 1.9725
# Epoch   0 Batch  230/538 - Train Accuracy: 0.5879, Validation Accuracy: 0.6012, Loss: 1.9621
# Epoch   0 Batch  240/538 - Train Accuracy: 0.6021, Validation Accuracy: 0.6223, Loss: 1.9679
# Epoch   0 Batch  250/538 - Train Accuracy: 0.5984, Validation Accuracy: 0.6088, Loss: 1.9322
# Epoch   0 Batch  260/538 - Train Accuracy: 0.6142, Validation Accuracy: 0.6268, Loss: 1.9431
# Epoch   0 Batch  270/538 - Train Accuracy: 0.5910, Validation Accuracy: 0.6214, Loss: 1.8827
# Epoch   0 Batch  280/538 - Train Accuracy: 0.6531, Validation Accuracy: 0.6358, Loss: 1.9266
# Epoch   0 Batch  290/538 - Train Accuracy: 0.6254, Validation Accuracy: 0.6481, Loss: 1.9298
# Epoch   0 Batch  300/538 - Train Accuracy: 0.6475, Validation Accuracy: 0.6211, Loss: 1.8816
# Epoch   0 Batch  310/538 - Train Accuracy: 0.6559, Validation Accuracy: 0.6481, Loss: 1.8956
# Epoch   0 Batch  320/538 - Train Accuracy: 0.6620, Validation Accuracy: 0.6648, Loss: 1.8410
# Epoch   0 Batch  330/538 - Train Accuracy: 0.6583, Validation Accuracy: 0.6451, Loss: 1.8523
# Epoch   0 Batch  340/538 - Train Accuracy: 0.6699, Validation Accuracy: 0.6548, Loss: 1.8022
# Epoch   0 Batch  350/538 - Train Accuracy: 0.6961, Validation Accuracy: 0.6923, Loss: 1.8937
# Epoch   0 Batch  360/538 - Train Accuracy: 0.6699, Validation Accuracy: 0.6879, Loss: 1.8679
# Epoch   0 Batch  370/538 - Train Accuracy: 0.6932, Validation Accuracy: 0.7008, Loss: 1.8053
# Epoch   0 Batch  380/538 - Train Accuracy: 0.6926, Validation Accuracy: 0.6774, Loss: 1.8393
# Epoch   0 Batch  390/538 - Train Accuracy: 0.7372, Validation Accuracy: 0.7079, Loss: 1.7924
# Epoch   0 Batch  400/538 - Train Accuracy: 0.7247, Validation Accuracy: 0.7072, Loss: 1.7667
# Epoch   0 Batch  410/538 - Train Accuracy: 0.7359, Validation Accuracy: 0.7148, Loss: 1.7621
# Epoch   0 Batch  420/538 - Train Accuracy: 0.7502, Validation Accuracy: 0.7271, Loss: 1.7238
# Epoch   0 Batch  430/538 - Train Accuracy: 0.7457, Validation Accuracy: 0.7198, Loss: 1.7352
# Epoch   0 Batch  440/538 - Train Accuracy: 0.7471, Validation Accuracy: 0.7466, Loss: 1.7469
# Epoch   0 Batch  450/538 - Train Accuracy: 0.7500, Validation Accuracy: 0.7537, Loss: 1.7610
# Epoch   0 Batch  460/538 - Train Accuracy: 0.7279, Validation Accuracy: 0.7486, Loss: 1.7206
# Epoch   0 Batch  470/538 - Train Accuracy: 0.7727, Validation Accuracy: 0.7548, Loss: 1.6612
# Epoch   0 Batch  480/538 - Train Accuracy: 0.7662, Validation Accuracy: 0.7534, Loss: 1.6942
# Epoch   0 Batch  490/538 - Train Accuracy: 0.7701, Validation Accuracy: 0.7480, Loss: 1.7535
# Epoch   0 Batch  500/538 - Train Accuracy: 0.7908, Validation Accuracy: 0.7438, Loss: 1.6636
# Epoch   0 Batch  510/538 - Train Accuracy: 0.7638, Validation Accuracy: 0.7640, Loss: 1.6267
# Epoch   0 Batch  520/538 - Train Accuracy: 0.7846, Validation Accuracy: 0.7649, Loss: 1.6571
# Epoch   0 Batch  530/538 - Train Accuracy: 0.7479, Validation Accuracy: 0.7587, Loss: 1.7263
# Epoch   1 Batch   10/538 - Train Accuracy: 0.7646, Validation Accuracy: 0.7612, Loss: 1.6466
# Epoch   1 Batch   20/538 - Train Accuracy: 0.7868, Validation Accuracy: 0.7818, Loss: 1.6565
# Epoch   1 Batch   30/538 - Train Accuracy: 0.7732, Validation Accuracy: 0.8011, Loss: 1.6278
# Epoch   1 Batch   40/538 - Train Accuracy: 0.8409, Validation Accuracy: 0.8230, Loss: 1.5603
# Epoch   1 Batch   50/538 - Train Accuracy: 0.8201, Validation Accuracy: 0.8082, Loss: 1.5702
# Epoch   1 Batch   60/538 - Train Accuracy: 0.8061, Validation Accuracy: 0.7827, Loss: 1.6163
# Epoch   1 Batch   70/538 - Train Accuracy: 0.8173, Validation Accuracy: 0.8081, Loss: 1.5696
# Epoch   1 Batch   80/538 - Train Accuracy: 0.7990, Validation Accuracy: 0.8162, Loss: 1.6158
# Epoch   1 Batch   90/538 - Train Accuracy: 0.8361, Validation Accuracy: 0.8077, Loss: 1.5803
# Epoch   1 Batch  100/538 - Train Accuracy: 0.8340, Validation Accuracy: 0.8155, Loss: 1.5693
# Epoch   1 Batch  110/538 - Train Accuracy: 0.8387, Validation Accuracy: 0.8450, Loss: 1.5512
# Epoch   1 Batch  120/538 - Train Accuracy: 0.8844, Validation Accuracy: 0.8427, Loss: 1.5874
# Epoch   1 Batch  130/538 - Train Accuracy: 0.8834, Validation Accuracy: 0.8512, Loss: 1.4867
# Epoch   1 Batch  140/538 - Train Accuracy: 0.8418, Validation Accuracy: 0.8420, Loss: 1.5997
# Epoch   1 Batch  150/538 - Train Accuracy: 0.8725, Validation Accuracy: 0.8638, Loss: 1.5163
# Epoch   1 Batch  160/538 - Train Accuracy: 0.8464, Validation Accuracy: 0.8578, Loss: 1.5585
# Epoch   1 Batch  170/538 - Train Accuracy: 0.8586, Validation Accuracy: 0.8588, Loss: 1.5048
# Epoch   1 Batch  180/538 - Train Accuracy: 0.8981, Validation Accuracy: 0.8862, Loss: 1.4902
# Epoch   1 Batch  190/538 - Train Accuracy: 0.8633, Validation Accuracy: 0.8814, Loss: 1.5879
# Epoch   1 Batch  200/538 - Train Accuracy: 0.8885, Validation Accuracy: 0.8681, Loss: 1.5572
# Epoch   1 Batch  210/538 - Train Accuracy: 0.8709, Validation Accuracy: 0.8944, Loss: 1.5234
# Epoch   1 Batch  220/538 - Train Accuracy: 0.8971, Validation Accuracy: 0.8867, Loss: 1.5295
# Epoch   1 Batch  230/538 - Train Accuracy: 0.8762, Validation Accuracy: 0.8967, Loss: 1.4934
# Epoch   1 Batch  240/538 - Train Accuracy: 0.8861, Validation Accuracy: 0.8956, Loss: 1.5470
# Epoch   1 Batch  250/538 - Train Accuracy: 0.9080, Validation Accuracy: 0.8732, Loss: 1.5197
# Epoch   1 Batch  260/538 - Train Accuracy: 0.8672, Validation Accuracy: 0.8821, Loss: 1.5407
# Epoch   1 Batch  270/538 - Train Accuracy: 0.9104, Validation Accuracy: 0.8967, Loss: 1.5024
# Epoch   1 Batch  280/538 - Train Accuracy: 0.9198, Validation Accuracy: 0.8990, Loss: 1.4776
# Epoch   1 Batch  290/538 - Train Accuracy: 0.9176, Validation Accuracy: 0.9107, Loss: 1.4845
# Epoch   1 Batch  300/538 - Train Accuracy: 0.9116, Validation Accuracy: 0.9158, Loss: 1.5209
# Epoch   1 Batch  310/538 - Train Accuracy: 0.9359, Validation Accuracy: 0.8970, Loss: 1.5085
# Epoch   1 Batch  320/538 - Train Accuracy: 0.9096, Validation Accuracy: 0.8958, Loss: 1.4611
# Epoch   1 Batch  330/538 - Train Accuracy: 0.9276, Validation Accuracy: 0.9018, Loss: 1.5278
# Epoch   1 Batch  340/538 - Train Accuracy: 0.9092, Validation Accuracy: 0.9029, Loss: 1.5085
# Epoch   1 Batch  350/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9093, Loss: 1.4730
# Epoch   1 Batch  360/538 - Train Accuracy: 0.9037, Validation Accuracy: 0.9151, Loss: 1.4550
# Epoch   1 Batch  370/538 - Train Accuracy: 0.9080, Validation Accuracy: 0.9098, Loss: 1.5226
# Epoch   1 Batch  380/538 - Train Accuracy: 0.9113, Validation Accuracy: 0.9091, Loss: 1.4912
# Epoch   1 Batch  390/538 - Train Accuracy: 0.9288, Validation Accuracy: 0.9183, Loss: 1.4376
# Epoch   1 Batch  400/538 - Train Accuracy: 0.9098, Validation Accuracy: 0.9100, Loss: 1.4766
# Epoch   1 Batch  410/538 - Train Accuracy: 0.9299, Validation Accuracy: 0.9098, Loss: 1.4557
# Epoch   1 Batch  420/538 - Train Accuracy: 0.9512, Validation Accuracy: 0.9174, Loss: 1.4532
# Epoch   1 Batch  430/538 - Train Accuracy: 0.9105, Validation Accuracy: 0.9150, Loss: 1.4647
# Epoch   1 Batch  440/538 - Train Accuracy: 0.9119, Validation Accuracy: 0.9244, Loss: 1.5295
# Epoch   1 Batch  450/538 - Train Accuracy: 0.9185, Validation Accuracy: 0.9158, Loss: 1.5151
# Epoch   1 Batch  460/538 - Train Accuracy: 0.8968, Validation Accuracy: 0.9146, Loss: 1.4734
# Epoch   1 Batch  470/538 - Train Accuracy: 0.9146, Validation Accuracy: 0.9039, Loss: 1.4626
# Epoch   1 Batch  480/538 - Train Accuracy: 0.9384, Validation Accuracy: 0.9098, Loss: 1.4760
# Epoch   1 Batch  490/538 - Train Accuracy: 0.9222, Validation Accuracy: 0.9130, Loss: 1.4512
# Epoch   1 Batch  500/538 - Train Accuracy: 0.9364, Validation Accuracy: 0.9107, Loss: 1.4709
# Epoch   1 Batch  510/538 - Train Accuracy: 0.9308, Validation Accuracy: 0.9139, Loss: 1.4644
# Epoch   1 Batch  520/538 - Train Accuracy: 0.9313, Validation Accuracy: 0.9178, Loss: 1.4284
# Epoch   1 Batch  530/538 - Train Accuracy: 0.9100, Validation Accuracy: 0.9208, Loss: 1.5168
# Epoch   2 Batch   10/538 - Train Accuracy: 0.9254, Validation Accuracy: 0.9180, Loss: 1.4709
# Epoch   2 Batch   20/538 - Train Accuracy: 0.9317, Validation Accuracy: 0.9183, Loss: 1.5126
# Epoch   2 Batch   30/538 - Train Accuracy: 0.9082, Validation Accuracy: 0.9130, Loss: 1.4846
# Epoch   2 Batch   40/538 - Train Accuracy: 0.9311, Validation Accuracy: 0.9292, Loss: 1.4403
# Epoch   2 Batch   50/538 - Train Accuracy: 0.9404, Validation Accuracy: 0.9261, Loss: 1.4152
# Epoch   2 Batch   60/538 - Train Accuracy: 0.9342, Validation Accuracy: 0.9306, Loss: 1.4814
# Epoch   2 Batch   70/538 - Train Accuracy: 0.9312, Validation Accuracy: 0.9197, Loss: 1.4676
# Epoch   2 Batch   80/538 - Train Accuracy: 0.9398, Validation Accuracy: 0.9366, Loss: 1.4549
# Epoch   2 Batch   90/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9208, Loss: 1.4701
# Epoch   2 Batch  100/538 - Train Accuracy: 0.9389, Validation Accuracy: 0.9355, Loss: 1.4717
# Epoch   2 Batch  110/538 - Train Accuracy: 0.9143, Validation Accuracy: 0.9357, Loss: 1.4243
# Epoch   2 Batch  120/538 - Train Accuracy: 0.9385, Validation Accuracy: 0.9270, Loss: 1.4447
# Epoch   2 Batch  130/538 - Train Accuracy: 0.9360, Validation Accuracy: 0.9217, Loss: 1.4691
# Epoch   2 Batch  140/538 - Train Accuracy: 0.9182, Validation Accuracy: 0.9233, Loss: 1.4864
# Epoch   2 Batch  150/538 - Train Accuracy: 0.9275, Validation Accuracy: 0.9272, Loss: 1.4578
# Epoch   2 Batch  160/538 - Train Accuracy: 0.9131, Validation Accuracy: 0.9295, Loss: 1.4387
# Epoch   2 Batch  170/538 - Train Accuracy: 0.9302, Validation Accuracy: 0.9274, Loss: 1.4466
# Epoch   2 Batch  180/538 - Train Accuracy: 0.9382, Validation Accuracy: 0.9217, Loss: 1.4751
# Epoch   2 Batch  190/538 - Train Accuracy: 0.9096, Validation Accuracy: 0.9348, Loss: 1.5169
# Epoch   2 Batch  200/538 - Train Accuracy: 0.9412, Validation Accuracy: 0.9347, Loss: 1.4152
# Epoch   2 Batch  210/538 - Train Accuracy: 0.9263, Validation Accuracy: 0.9315, Loss: 1.4274
# Epoch   2 Batch  220/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9221, Loss: 1.4270
# Epoch   2 Batch  230/538 - Train Accuracy: 0.9240, Validation Accuracy: 0.9419, Loss: 1.5027
# Epoch   2 Batch  240/538 - Train Accuracy: 0.9437, Validation Accuracy: 0.9270, Loss: 1.5034
# Epoch   2 Batch  250/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9386, Loss: 1.5069
# Epoch   2 Batch  260/538 - Train Accuracy: 0.9005, Validation Accuracy: 0.9205, Loss: 1.4236
# Epoch   2 Batch  270/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9233, Loss: 1.4628
# Epoch   2 Batch  280/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9341, Loss: 1.4550
# Epoch   2 Batch  290/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9325, Loss: 1.4402
# Epoch   2 Batch  300/538 - Train Accuracy: 0.9505, Validation Accuracy: 0.9318, Loss: 1.4290
# Epoch   2 Batch  310/538 - Train Accuracy: 0.9592, Validation Accuracy: 0.9462, Loss: 1.4936
# Epoch   2 Batch  320/538 - Train Accuracy: 0.9475, Validation Accuracy: 0.9339, Loss: 1.4871
# Epoch   2 Batch  330/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9309, Loss: 1.4648
# Epoch   2 Batch  340/538 - Train Accuracy: 0.9432, Validation Accuracy: 0.9405, Loss: 1.4428
# Epoch   2 Batch  350/538 - Train Accuracy: 0.9548, Validation Accuracy: 0.9247, Loss: 1.4372
# Epoch   2 Batch  360/538 - Train Accuracy: 0.9436, Validation Accuracy: 0.9478, Loss: 1.4905
# Epoch   2 Batch  370/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9382, Loss: 1.4994
# Epoch   2 Batch  380/538 - Train Accuracy: 0.9465, Validation Accuracy: 0.9524, Loss: 1.4450
# Epoch   2 Batch  390/538 - Train Accuracy: 0.9487, Validation Accuracy: 0.9510, Loss: 1.4881
# Epoch   2 Batch  400/538 - Train Accuracy: 0.9548, Validation Accuracy: 0.9386, Loss: 1.4728
# Epoch   2 Batch  410/538 - Train Accuracy: 0.9547, Validation Accuracy: 0.9380, Loss: 1.4583
# Epoch   2 Batch  420/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9391, Loss: 1.4613
# Epoch   2 Batch  430/538 - Train Accuracy: 0.9277, Validation Accuracy: 0.9348, Loss: 1.4800
# Epoch   2 Batch  440/538 - Train Accuracy: 0.9455, Validation Accuracy: 0.9423, Loss: 1.4968
# Epoch   2 Batch  450/538 - Train Accuracy: 0.9263, Validation Accuracy: 0.9387, Loss: 1.4612
# Epoch   2 Batch  460/538 - Train Accuracy: 0.9167, Validation Accuracy: 0.9540, Loss: 1.4680
# Epoch   2 Batch  470/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9405, Loss: 1.4252
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9563, Validation Accuracy: 0.9361, Loss: 1.4113
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9444, Validation Accuracy: 0.9586, Loss: 1.4480
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9739, Validation Accuracy: 0.9412, Loss: 1.4707
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9242, Loss: 1.4481
# Epoch   2 Batch  520/538 - Train Accuracy: 0.9471, Validation Accuracy: 0.9464, Loss: 1.4675
# Epoch   2 Batch  530/538 - Train Accuracy: 0.9523, Validation Accuracy: 0.9645, Loss: 1.4408
# Epoch   3 Batch   10/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9380, Loss: 1.4895
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9516, Validation Accuracy: 0.9437, Loss: 1.4358
# Epoch   3 Batch   30/538 - Train Accuracy: 0.9555, Validation Accuracy: 0.9418, Loss: 1.4703
# Epoch   3 Batch   40/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9506, Loss: 1.4407
# Epoch   3 Batch   50/538 - Train Accuracy: 0.9406, Validation Accuracy: 0.9450, Loss: 1.4675
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9494, Validation Accuracy: 0.9416, Loss: 1.4623
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9511, Validation Accuracy: 0.9396, Loss: 1.3874
# Epoch   3 Batch   80/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9519, Loss: 1.3988
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9545, Loss: 1.4395
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9535, Validation Accuracy: 0.9467, Loss: 1.4207
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9492, Loss: 1.4018
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9598, Validation Accuracy: 0.9434, Loss: 1.4089
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9565, Validation Accuracy: 0.9549, Loss: 1.4061
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9521, Validation Accuracy: 0.9489, Loss: 1.4803
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9602, Loss: 1.4345
# Epoch   3 Batch  160/538 - Train Accuracy: 0.9399, Validation Accuracy: 0.9411, Loss: 1.4430
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9453, Validation Accuracy: 0.9451, Loss: 1.3973
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9466, Validation Accuracy: 0.9577, Loss: 1.4469
# Epoch   3 Batch  190/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9430, Loss: 1.4800
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9519, Loss: 1.4335
# Epoch   3 Batch  210/538 - Train Accuracy: 0.9364, Validation Accuracy: 0.9538, Loss: 1.4321
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9517, Loss: 1.4311
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9504, Validation Accuracy: 0.9560, Loss: 1.4897
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9486, Validation Accuracy: 0.9521, Loss: 1.4057
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9551, Validation Accuracy: 0.9547, Loss: 1.4512
# Epoch   3 Batch  260/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9354, Loss: 1.4415
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9582, Validation Accuracy: 0.9480, Loss: 1.3958
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9591, Validation Accuracy: 0.9482, Loss: 1.4551
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9646, Validation Accuracy: 0.9554, Loss: 1.4153
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9535, Loss: 1.4099
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9625, Validation Accuracy: 0.9577, Loss: 1.4447
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9593, Validation Accuracy: 0.9588, Loss: 1.4205
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9715, Validation Accuracy: 0.9545, Loss: 1.4368
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9579, Loss: 1.4344
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9673, Validation Accuracy: 0.9581, Loss: 1.4569
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9551, Validation Accuracy: 0.9577, Loss: 1.4060
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9531, Validation Accuracy: 0.9453, Loss: 1.4162
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9533, Loss: 1.4522
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9578, Validation Accuracy: 0.9636, Loss: 1.4409
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9555, Validation Accuracy: 0.9522, Loss: 1.4654
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9613, Loss: 1.4668
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9631, Validation Accuracy: 0.9597, Loss: 1.4394
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9445, Validation Accuracy: 0.9482, Loss: 1.4541
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9646, Validation Accuracy: 0.9558, Loss: 1.4154
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9392, Validation Accuracy: 0.9627, Loss: 1.4050
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9519, Loss: 1.3904
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9669, Validation Accuracy: 0.9602, Loss: 1.4877
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9626, Validation Accuracy: 0.9508, Loss: 1.4614
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9641, Loss: 1.4038
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9782, Validation Accuracy: 0.9565, Loss: 1.3851
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9597, Loss: 1.4796
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9680, Loss: 1.3937
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9576, Loss: 1.4088
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9547, Validation Accuracy: 0.9600, Loss: 1.4271
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9705, Loss: 1.3979
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9625, Loss: 1.3953
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9563, Validation Accuracy: 0.9675, Loss: 1.4960
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9588, Validation Accuracy: 0.9664, Loss: 1.3754
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9691, Validation Accuracy: 0.9705, Loss: 1.4774
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9675, Loss: 1.4236
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9703, Validation Accuracy: 0.9631, Loss: 1.4293
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9674, Validation Accuracy: 0.9600, Loss: 1.4832
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9850, Validation Accuracy: 0.9609, Loss: 1.4172
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9660, Validation Accuracy: 0.9538, Loss: 1.4305
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9639, Validation Accuracy: 0.9586, Loss: 1.4255
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9503, Validation Accuracy: 0.9600, Loss: 1.4193
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9494, Validation Accuracy: 0.9634, Loss: 1.3877
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9735, Loss: 1.4381
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9650, Loss: 1.4256
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9652, Validation Accuracy: 0.9652, Loss: 1.4818
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9585, Validation Accuracy: 0.9494, Loss: 1.4387
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9510, Loss: 1.3852
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9613, Loss: 1.4268
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9604, Validation Accuracy: 0.9517, Loss: 1.4544
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9444, Validation Accuracy: 0.9609, Loss: 1.4268
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9645, Loss: 1.4626
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9633, Validation Accuracy: 0.9599, Loss: 1.4233
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9631, Validation Accuracy: 0.9521, Loss: 1.4346
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9599, Loss: 1.4445
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9632, Loss: 1.4206
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9728, Validation Accuracy: 0.9592, Loss: 1.4440
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9748, Validation Accuracy: 0.9499, Loss: 1.3926
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9650, Loss: 1.4422
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9602, Loss: 1.4193
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9664, Loss: 1.3827
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9567, Loss: 1.4276
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9668, Validation Accuracy: 0.9663, Loss: 1.4513
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9589, Validation Accuracy: 0.9627, Loss: 1.4263
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9730, Loss: 1.4373
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9586, Validation Accuracy: 0.9604, Loss: 1.4115
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9629, Validation Accuracy: 0.9560, Loss: 1.4504
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9551, Loss: 1.4188
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9593, Validation Accuracy: 0.9592, Loss: 1.4396
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9586, Loss: 1.4525
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9618, Loss: 1.4757
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9563, Validation Accuracy: 0.9744, Loss: 1.4788
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9600, Loss: 1.4674
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9438, Validation Accuracy: 0.9654, Loss: 1.4546
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9710, Validation Accuracy: 0.9620, Loss: 1.4732
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9513, Loss: 1.4281
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9634, Validation Accuracy: 0.9627, Loss: 1.4414
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9609, Loss: 1.4487
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9673, Validation Accuracy: 0.9531, Loss: 1.4288
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9579, Loss: 1.4555
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9666, Validation Accuracy: 0.9494, Loss: 1.4970
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9695, Loss: 1.3842
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    unknown = vocab_to_int['<UNK>']
    sentence = sentence.lower()
    return [vocab_to_int.get(w, unknown) for w in sentence.split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [54, 20, 53, 188, 72, 18, 171]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [305, 204, 326, 142, 292, 166, 246, 154, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
